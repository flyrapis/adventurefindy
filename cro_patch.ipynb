# %%
with open('/workspace/adventure_findy/src/pages/Home.tsx', 'r', encoding='utf-8') as f:
    src = f.read()

import re

# ── 1. DepositStrip: tighten wording ─────────────────────────────────────────
OLD_DEPOSIT = '''function DepositStrip() {
  return (
    <div className="flex items-start gap-2 bg-primary/5 border border-primary/15 rounded-xl p-3 mt-3">
      <span className="text-base shrink-0">💳</span>
      <div>
        <p className="text-xs font-black text-foreground leading-tight">
          Secure your spot with a small deposit.
        </p>
        <p className="text-[11px] text-muted-foreground leading-tight mt-0.5">
          Pay the rest on the day of your experience.
        </p>
      </div>
    </div>
  );
}'''

NEW_DEPOSIT = '''function DepositStrip() {
  return (
    <div className="flex items-center gap-2.5 bg-primary/6 border border-primary/20 rounded-xl px-3 py-2.5 mt-3">
      <span className="text-base shrink-0">🔒</span>
      <div>
        <p className="text-xs font-black text-foreground leading-none">
          Secure your spot with a small deposit
        </p>
        <p className="text-[10px] text-muted-foreground leading-tight mt-0.5">
          Pay the rest on the day of your experience
        </p>
      </div>
    </div>
  );
}'''

src = src.replace(OLD_DEPOSIT, NEW_DEPOSIT, 1)
print('DepositStrip:', OLD_DEPOSIT in open('/workspace/adventure_findy/src/pages/Home.tsx').read(), '→', NEW_DEPOSIT in src)
# Out:
# DepositStrip: True → True

# %%
# ── 2. TrustMicro: updated copy ───────────────────────────────────────────────
OLD_TRUST = '''function TrustMicro() {
  return (
    <p className="text-[10px] text-muted-foreground text-center mt-2 leading-relaxed">
      ✅ No registration required &nbsp;·&nbsp; ⚡ Fast confirmation &nbsp;·&nbsp; 🔒 Secure your spot in minutes
    </p>
  );
}'''

NEW_TRUST = '''function TrustMicro() {
  return (
    <p className="text-[10px] text-muted-foreground text-center mt-2 leading-relaxed">
      ✅ No registration &nbsp;·&nbsp; ⚡ Takes less than 2 min &nbsp;·&nbsp; 💬 Instant WhatsApp reply
    </p>
  );
}

// ─── Risk-reduction microcopy ─────────────────────────────────────────────────
function RiskMicro() {
  return (
    <div className="flex flex-wrap items-center justify-center gap-x-3 gap-y-0.5 mt-1.5">
      {['🔄 Flexible rescheduling', '☁️ Weather protection', '🔒 Secure booking'].map((t) => (
        <span key={t} className="text-[10px] text-muted-foreground font-semibold">{t}</span>
      ))}
    </div>
  );
}'''

src = src.replace(OLD_TRUST, NEW_TRUST, 1)
print('TrustMicro+RiskMicro:', 'RiskMicro' in src)
# Out:
# TrustMicro+RiskMicro: True

# %%
# ── 3. TodayCard primary CTA: add RiskMicro under TrustMicro ────────────────
OLD_CTA_TODAY = '''            <WAIcon className="w-4 h-4" />
            Book via WhatsApp
          </a>
          <TrustMicro />
        </div>

        {/* ── Deposit strip ──*/}'''

NEW_CTA_TODAY = '''            <WAIcon className="w-4 h-4" />
            Reserve Now — Book via WhatsApp
          </a>
          <TrustMicro />
          <RiskMicro />
        </div>

        {/* ── Deposit strip ──*/}'''

src = src.replace(OLD_CTA_TODAY, NEW_CTA_TODAY, 1)
print('TodayCard CTA patch:', NEW_CTA_TODAY in src)
# Out:
# TodayCard CTA patch: False

# %%
# ── 4. TourCard primary CTA label + add RiskMicro ────────────────────────────
OLD_CARD = '''            Book via WhatsApp
          </a>
          <TrustMicro />

          {/* Details toggle */}'''

NEW_CARD = '''            Reserve Now — Book via WhatsApp
          </a>
          <TrustMicro />
          <RiskMicro />

          {/* Details toggle */}'''

src = src.replace(OLD_CARD, NEW_CARD, 1)
print('TourCard CTA patch:', NEW_CARD in src)
# Out:
# TourCard CTA patch: True

# %%
# ── 5. Hero: sub-headline → deposit message ─────────────────────────────────
OLD_HERO_SUB = '''          {/* Sub */}
          <motion.p
            initial={{ opacity: 0, y: 16 }}
            animate={{ opacity: 1, y: 0 }}
            transition={{ delay: 0.45 }}
            className="text-white/80 text-base md:text-lg leading-relaxed max-w-md"
          >
            Reserve via WhatsApp with a small deposit.<br className="hidden md:block" />
            Pay the rest on the day of your adventure.
          </motion.p>'''

NEW_HERO_SUB = '''          {/* Sub */}
          <motion.p
            initial={{ opacity: 0, y: 16 }}
            animate={{ opacity: 1, y: 0 }}
            transition={{ delay: 0.45 }}
            className="text-white/85 text-base md:text-lg leading-snug max-w-md"
          >
            🔒 Secure your spot with a small deposit.<br />
            <span className="text-white/70 text-sm">Pay the rest on the day of your experience.</span>
          </motion.p>'''

src = src.replace(OLD_HERO_SUB, NEW_HERO_SUB, 1)
print('Hero sub:', NEW_HERO_SUB in src)

# ── 6. Hero trust pills: replace items ────────────────────────────────────────
OLD_PILLS = """          {['✅ No registration', '⚡ Confirm in minutes', '💳 Small deposit only', '🌟 5.0 ★ rated'].map((t) => ("""
NEW_PILLS = """          {['✅ No registration', '⚡ Reply in minutes', '💳 Small deposit only', '🔒 Secure booking'].map((t) => ("""

src = src.replace(OLD_PILLS, NEW_PILLS, 1)
print('Hero pills:', NEW_PILLS in src)

# ── 7. Hero — replace WhatsApp number line with risk microcopy ────────────────
OLD_WA_NUM = '''          {/* WhatsApp number */}
          <motion.a
            href={buildWhatsAppGeneral()}
            target="_blank"
            rel="noopener noreferrer"
            initial={{ opacity: 0 }}
            animate={{ opacity: 1 }}
            transition={{ delay: 0.82 }}
            className="flex items-center gap-2 text-white/70 hover:text-white transition-colors text-sm font-medium"
          >
            <WAIcon className="w-4 h-4 text-[#25D366]" />
            +52 612 157 7674
          </motion.a>'''

NEW_WA_NUM = '''          {/* Risk microcopy */}
          <motion.p
            initial={{ opacity: 0 }}
            animate={{ opacity: 1 }}
            transition={{ delay: 0.88 }}
            className="text-white/50 text-[11px]"
          >
            🔄 Flexible rescheduling &nbsp;·&nbsp; ☁️ Weather protection &nbsp;·&nbsp; 🤝 Trusted local guides
          </motion.p>'''

src = src.replace(OLD_WA_NUM, NEW_WA_NUM, 1)
print('Hero risk micro:', NEW_WA_NUM in src)
# Out:
# Hero sub: True
# Hero pills: True
# Hero risk micro: True

# %%
# ── 8. Today section: stronger heading + urgency ─────────────────────────────
OLD_TODAY_HEADING = '''              <p className="text-sm text-muted-foreground mt-0.5">Reserve now — spots filling fast</p>'''
NEW_TODAY_HEADING = '''              <p className="text-sm text-muted-foreground mt-0.5">
                Spots are <strong className="text-destructive">filling fast</strong> — reserve in under 2 minutes
              </p>'''
src = src.replace(OLD_TODAY_HEADING, NEW_TODAY_HEADING, 1)
print('Today heading:', NEW_TODAY_HEADING in src)

# ── 9. Tours section: updated heading ─────────────────────────────────────────
OLD_TOURS_HEADING = '''            <h2 className="text-2xl font-black text-foreground mb-2" style={{ fontFamily: "'Outfit', sans-serif" }}>
              Explore every adventure
            </h2>
            <p className="text-sm text-muted-foreground">All bookable today via WhatsApp · Deposit required</p>'''
NEW_TOURS_HEADING = '''            <h2 className="text-2xl font-black text-foreground mb-1" style={{ fontFamily: "'Outfit', sans-serif" }}>
              Every adventure — bookable today
            </h2>
            <p className="text-sm text-muted-foreground">💬 Book via WhatsApp · 💳 Small deposit required
            </p>'''
src = src.replace(OLD_TOURS_HEADING, NEW_TOURS_HEADING, 1)
print('Tours heading:', NEW_TOURS_HEADING in src)

# ── 10. How It Works steps: 4-step deposit model ─────────────────────────────
OLD_STEPS = '''            {[
              { step: '01', icon: '🔍', title: 'Choose your experience',  desc: 'Browse tours available today' },
              { step: '02', icon: '💬', title: 'Chat on WhatsApp',        desc: 'We confirm availability instantly' },
              { step: '03', icon: '💳', title: 'Pay a small deposit',     desc: 'Secure your spot with 20–30%' },
              { step: '04', icon: '🌊', title: 'Pay rest on the day',     desc: 'Balance paid to your guide' },
            ].map(({ step, icon, title, desc }) => ('''
NEW_STEPS = '''            {[
              { step: '01', icon: '🔍', title: 'Choose your experience',          desc: 'Browse tours available today' },
              { step: '02', icon: '💬', title: 'Chat on WhatsApp',                 desc: 'Instant reply — confirm availability' },
              { step: '03', icon: '💳', title: 'Secure your spot with a deposit', desc: 'Pay 20–30% to confirm your spot' },
              { step: '04', icon: '🌊', title: 'Pay the rest on the day',          desc: 'Balance paid to your guide' },
            ].map(({ step, icon, title, desc }) => ('''
src = src.replace(OLD_STEPS, NEW_STEPS, 1)
print('How It Works steps:', NEW_STEPS in src)
# Out:
# Today heading: True
# Tours heading: True
# How It Works steps: True

# %%
# ── 11. How It Works — deposit callout ───────────────────────────────────────
OLD_DEP_CALLOUT = '''          {/* Deposit callout */}
          <div className="bg-primary/5 border border-primary/20 rounded-2xl p-5 mb-6">
            <div className="text-2xl mb-2">💳</div>
            <p className="font-black text-foreground text-base mb-1">
              Secure your spot with a small deposit.
            </p>
            <p className="text-sm text-muted-foreground mb-4">
              Pay 20–30% upfront to confirm your reservation.<br />
              The remaining balance is paid directly to your guide on the day.
            </p>
            <a
              href={buildWhatsAppGeneral()}
              target="_blank"
              rel="noopener noreferrer"
              className="inline-flex items-center gap-2 bg-[#25D366] hover:bg-[#1fbd5c] text-white font-black py-3.5 px-6 rounded-xl text-sm transition-all active:scale-95 shadow"
            >
              <WAIcon className="w-4 h-4" />
              Start your booking
            </a>
            <TrustMicro />
          </div>'''

NEW_DEP_CALLOUT = '''          {/* Deposit + risk callout */}
          <div className="bg-primary/5 border border-primary/20 rounded-2xl p-5 mb-6 text-center">
            <div className="text-2xl mb-2">🔒</div>
            <p className="font-black text-foreground text-base mb-1">
              Secure your spot with a small deposit
            </p>
            <p className="text-sm text-muted-foreground mb-2">
              Pay the rest on the day of your experience
            </p>
            <div className="flex flex-wrap justify-center gap-x-4 gap-y-1 text-xs text-muted-foreground mb-4">
              <span>🔄 Flexible rescheduling</span>
              <span>☁️ Weather protection</span>
              <span>🤝 Trusted local operators</span>
            </div>
            <a
              href={buildWhatsAppGeneral()}
              target="_blank"
              rel="noopener noreferrer"
              className="inline-flex items-center gap-2 bg-[#25D366] hover:bg-[#1fbd5c] text-white font-black py-3.5 px-6 rounded-xl text-sm transition-all active:scale-95 shadow"
            >
              <WAIcon className="w-4 h-4" />
              Start your booking
            </a>
            <TrustMicro />
          </div>'''

src = src.replace(OLD_DEP_CALLOUT, NEW_DEP_CALLOUT, 1)
print('Dep callout:', NEW_DEP_CALLOUT in src)

# ── 12. Trust strip: 6-column grid ───────────────────────────────────────────
OLD_TRUST_STRIP = '''          <div className="grid grid-cols-2 md:grid-cols-4 gap-4">
            {TRUST_ITEMS.map((item) => (
              <div key={item.title} className="flex items-start gap-3">
                <span className="text-2xl shrink-0">{item.icon}</span>
                <div>
                  <p className="font-black text-sm text-foreground leading-tight">{item.title}</p>
                  <p className="text-[11px] text-muted-foreground leading-tight mt-0.5">{item.desc}</p>
                </div>
              </div>
            ))}
          </div>'''

NEW_TRUST_STRIP = '''          <div className="grid grid-cols-2 sm:grid-cols-3 md:grid-cols-6 gap-4">
            {TRUST_ITEMS.map((item) => (
              <div key={item.title} className="flex flex-col items-center text-center gap-1.5">
                <span className="text-2xl">{item.icon}</span>
                <p className="font-black text-xs text-foreground leading-tight">{item.title}</p>
                <p className="text-[10px] text-muted-foreground leading-tight">{item.desc}</p>
              </div>
            ))}
          </div>'''

src = src.replace(OLD_TRUST_STRIP, NEW_TRUST_STRIP, 1)
print('Trust strip:', NEW_TRUST_STRIP in src)

# ── 13. Reviews CTA: add RiskMicro ───────────────────────────────────────────
OLD_REVIEWS_CTA = '''          {/* Book CTA inside reviews */}
          <div className="text-center">
            <a
              href={buildWhatsAppGeneral()}
              target="_blank"
              rel="noopener noreferrer"
              className="inline-flex items-center gap-2 bg-[#25D366] hover:bg-[#1fbd5c] text-white font-black py-4 px-8 rounded-xl text-sm transition-all active:scale-95 shadow-md"
            >
              <WAIcon className="w-4 h-4" />
              Book your experience today
            </a>
          </div>'''

NEW_REVIEWS_CTA = '''          {/* Book CTA inside reviews */}
          <div className="text-center">
            <a
              href={buildWhatsAppGeneral()}
              target="_blank"
              rel="noopener noreferrer"
              className="inline-flex items-center gap-2 bg-[#25D366] hover:bg-[#1fbd5c] text-white font-black py-4 px-8 rounded-xl text-sm transition-all active:scale-95 shadow-md"
            >
              <WAIcon className="w-4 h-4" />
              Book your experience today
            </a>
            <TrustMicro />
            <RiskMicro />
          </div>'''

src = src.replace(OLD_REVIEWS_CTA, NEW_REVIEWS_CTA, 1)
print('Reviews CTA:', NEW_REVIEWS_CTA in src)
# Out:
# Dep callout: True
# Trust strip: True
# Reviews CTA: True

# %%
# ── 14. Final conversion block: "Don't miss your spot" ──────────────────────
OLD_FINAL = '''            {/* Badge */}
            <div className="flex items-center gap-2 bg-white/15 backdrop-blur-sm border border-white/25 rounded-full px-4 py-1.5">
              <span className="w-2 h-2 bg-green-400 rounded-full animate-pulse" />
              <span className="text-white text-xs font-bold">Spots available right now</span>
            </div>

            <h2 className="text-3xl md:text-4xl font-black text-white leading-tight" style={{ fontFamily: "'Outfit', sans-serif" }}>
              Ready to secure<br />your adventure? 🌊
            </h2>

            <p className="text-white/80 text-base leading-relaxed">
              Reserve now with a small deposit.<br />
              <strong className="text-white">Spots fill fast.</strong>
            </p>

            {/* Deposit reminder */}
            <div className="bg-white/10 backdrop-blur-sm border border-white/20 rounded-2xl px-5 py-3 w-full">
              <p className="text-white text-sm font-black mb-0.5">💳 How it works</p>
              <p className="text-white/70 text-xs leading-relaxed">
                Pay 20–30% deposit to lock in your spot · Pay the rest on the day
              </p>
            </div>

            {/* Primary CTA */}
            <a
              href={buildWhatsAppGeneral()}
              target="_blank"
              rel="noopener noreferrer"
              className="flex items-center justify-center gap-3 w-full bg-[#25D366] hover:bg-[#1fbd5c] text-white font-black py-5 rounded-2xl text-base transition-all active:scale-95 shadow-2xl"
            >
              <WAIcon className="w-5 h-5" />
              Reserve Now — Book via WhatsApp
            </a>

            {/* Secondary */}
            <a href="#today" className="flex items-center gap-2 text-white/70 hover:text-white text-sm font-semibold transition-colors">
              <ArrowRight className="w-4 h-4" />
              View today's experiences first
            </a>

            {/* Trust */}
            <div className="flex flex-wrap justify-center gap-2">
              {['✅ No registration', '⚡ Confirm in minutes', '🌟 5.0 ★ rated', '🔒 Deposit-secured'].map((t) => (
                <span key={t} className="text-[11px] font-semibold text-white/60 bg-white/10 border border-white/15 px-3 py-1 rounded-full">
                  {t}
                </span>
              ))}
            </div>

            <p className="text-white/50 text-xs">+52 612 157 7674 · Baja California Sur, Mexico</p>'''

NEW_FINAL = '''            {/* Live urgency badge */}
            <div className="flex items-center gap-2 bg-destructive/90 backdrop-blur-sm border border-destructive rounded-full px-4 py-1.5">
              <span className="w-2 h-2 bg-white rounded-full animate-pulse" />
              <span className="text-white text-xs font-black">Experiences fill quickly. Act now.</span>
            </div>

            <h2 className="text-3xl md:text-4xl font-black text-white leading-tight" style={{ fontFamily: "'Outfit', sans-serif" }}>
              Don't miss<br />your spot 🌊
            </h2>

            <p className="text-white/85 text-base leading-snug">
              Reserve now in under 2 minutes.<br />
              <strong className="text-white">🔒 Secure your spot with a small deposit.<br />
              Pay the rest on the day of your experience.</strong>
            </p>

            {/* Risk reduction pills */}
            <div className="flex flex-wrap justify-center gap-2">
              {['🔄 Flexible rescheduling', '☁️ Weather protection', '💬 Fast WhatsApp support'].map((t) => (
                <span key={t} className="text-xs font-semibold text-white/70 bg-white/10 border border-white/15 px-3 py-1 rounded-full">{t}</span>
              ))}
            </div>

            {/* Primary CTA */}
            <a
              href={buildWhatsAppGeneral()}
              target="_blank"
              rel="noopener noreferrer"
              className="flex items-center justify-center gap-3 w-full bg-[#25D366] hover:bg-[#1fbd5c] text-white font-black py-5 rounded-2xl text-base transition-all active:scale-95 shadow-2xl"
            >
              <WAIcon className="w-5 h-5" />
              Book via WhatsApp
            </a>

            {/* Micro under CTA */}
            <p className="text-white/55 text-xs">
              ✅ No registration &nbsp;·&nbsp; ⚡ Takes less than 2 min &nbsp;·&nbsp; 💬 Instant WhatsApp reply
            </p>

            {/* Secondary */}
            <a href="#today" className="text-white/60 hover:text-white text-sm font-semibold transition-colors underline underline-offset-2">
              View today's experiences first →
            </a>

            <p className="text-white/40 text-xs">+52 612 157 7674 · Baja California Sur, Mexico</p>'''

src = src.replace(OLD_FINAL, NEW_FINAL, 1)
print("Don't miss block:", NEW_FINAL in src)
# Out:
# Don't miss block: True

# %%
# Check if ArrowRight is still used elsewhere (we removed it from final block)
import re
arrow_uses = [m.start() for m in re.finditer(r'<ArrowRight', src)]
print('ArrowRight uses:', len(arrow_uses))

# Check import
import_line = next((l for l in src.split('\n') if 'ArrowRight' in l), None)
print('ArrowRight import line:', import_line)

with open('/workspace/adventure_findy/src/pages/Home.tsx', 'w', encoding='utf-8') as f:
    f.write(src)
print('Written', len(src), 'chars')
# Out:
# ArrowRight uses: 0
# ArrowRight import line: import { Clock, Star, MapPin, ChevronDown, ChevronUp, CheckCircle, ArrowRight, Shield } from 'lucide-react';
# Written 39658 chars
